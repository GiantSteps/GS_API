# %% [markdown]
# # GS-API examples

# %% [markdown]
# If not installed gsapi python module yet, follow the instructions:
#
# Download : https://github.com/GiantSteps/GS_API
#
# Open terminal:
# - cd GS_API/python
# - python setup.py build
# - python setup.py install

# %%
# Import the GS API module
from gsapi import GSPattern

# %% [markdown]
# All submodules within API provide help by typing help(Name of the module)

# %%
help(GSPattern)
#help(GSBassmineAnalysis)
# Out:
# Help on module gsapi.GSPattern in gsapi:
#
# NAME
#     gsapi.GSPattern
#
# FILE
#     /Library/Frameworks/Python.framework/Versions/2.7/lib/python2.7/site-packages/gsapi-1.0-py2.7.egg/gsapi/GSPattern.py
#
# CLASSES
#     __builtin__.object
#         GSPattern
#         GSPatternEvent
#
#     class GSPattern(__builtin__.object)
#      |  Class representing a pattern made of GSPatternEvent
#      |
#      |  holds a list of GSEvents and provide basic manipulation function
#      |
#      |  Args:
#      |          duration: length of pattern usually in beat, but time scale is up to the user (can be useful if working on 32th note steps)
#      |          events: list of GSPatternEvent for this pattern
#      |          bpm:origin BPM for this pattern (default: 120)
#      |          timeSignature: list of integer representing time signature ; i.e [numerator,denominator]
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self)
#      |
#      |  __repr__(self)
#      |      Nicely print out the list of events
#      |
#      |      each line represents an event formatted as  : tags pitch startTime duration
#      |
#      |  addEvent(self, GSPatternEvent)
#      |      Add an event increasing duration if needed
#      |
#      |      Args:
#      |              GSPatternEvent : the event to be added
#      |
#      |  alignOnGrid(self, stepSize, repeatibleTags=['silence'])
#      |      align this pattern on a temporal grid
#      |
#      |      very useful to deal with step-sequenced pattern :
#      |              - all events durations are shortened to stepsize
#      |              - all events startTimes are quantified to stepsize
#      |
#      |      repeatibleTags allow to deal with `silences type` of events :
#      |              - if a silence spread over more than one stepsize, we generate an event for each stepSize
#      |
#      |      thus each step is ensured to be filled with one distinct event at least
#      |      Args:
#      |              stepSize: temporal definition of the grid
#      |
#      |  copy(self)
#      |      Deepcopy a pattern
#      |
#      |  fillWithSilences(self, maxSilenceTime=0, perTag=False, silenceTag='silence')
#      |      Fill empty (i.e no event ) spaces with silence event
#      |
#      |      Args:
#      |              maxSilenceTime : if positive value is given, will add multiple silence of maxSilenceTime for empty time larger than maxSilenceTime
#      |              perTag: fill silence for each Tag
#      |              silenceTag: tag that will be used when inserting the silence event
#      |
#      |  fromJSONDict(self, json)
#      |      Loads a json API dict object to this pattern
#      |
#      |      Args:
#      |              json: a dict created from reading json file with GS API JSON format
#      |
#      |  getACopyWithoutEvents(self)
#      |      copy all fields but events
#      |
#      |      useful for creating patterns from patterns
#      |
#      |  getActiveEventsAtTime(self, time)
#      |      Get all events currently active at a givent time
#      |
#      |      Args:
#      |              time: time asked for
#      |              tolerance: admited deviation of start time
#      |      Returns:
#      |              list of events
#      |
#      |  getAllIdenticalEvents(self, event, allTagsMustBeEquals=True)
#      |      Get a list of event with same tags
#      |
#      |      Args:
#      |              event:event to compare with
#      |              allTagsMustBeEquals : shall we get exact tags equality or be fine with one common tag
#      |      Returns:
#      |              list of events that have all or one tags in common
#      |
#      |  getAllTags(self)
#      |      Returns all used tags in this pattern
#      |
#      |      Returns:
#      |              list of string composed of all possible tags
#      |
#      |  getFilledWithSilences(self, maxSilenceTime=0, perTag=False, silenceTag='silence')
#      |
#      |  getLastNoteOff(self)
#      |      Gets last event end time
#      |
#      |      Returns:
#      |              lastNoteOff, i.e the time corresponding to the end of the last event
#      |
#      |  getPatternForTimeSlice(self, startTime, length, trimEnd=True)
#      |      Returns a pattern within given timeslice
#      |
#      |      Args:
#      |              startTime: start time for time slice
#      |              length: length of time slice
#      |              trimEnd: cut any events that ends after startTime + length
#      |      Returns:
#      |              a new GSpattern within time slice
#      |
#      |  getPatternWithTags(self, tags, exactSearch=True, copy=True)
#      |      Returns a sub-pattern with the given tags
#      |
#      |      Args:
#      |              tags: string list or lambda  expression (return boolean based on tag list input): tags to be checked for
#      |              exactSearch: bool : if True the tags have to be exactly the same, else they can be included in events Tags
#      |              copy: do we return a copy of original events (avoid modifying originating events when modifying the returned subpattern)
#      |      Returns:
#      |              a GSPattern with only events that tags corresponds to given tags
#      |
#      |  getPatternWithoutTags(self, tags, exactSearch=False, copy=True)
#      |      Returns a sub-pattern without the given tags
#      |
#      |      Args:
#      |              tags: string list : tags to be checked for
#      |              exactSearch: bool : if True the tags have to be exactly the same, else they can be included in events Tags
#      |              copy: do we return a copy of original events (avoid modifying originating events when modifying the returned subpattern)
#      |      Returns:
#      |              a GSPattern with events without given tags
#      |
#      |  getStartingEventsAtTime(self, time, tolerance=0)
#      |      Get all events activating at a givent time
#      |
#      |      Args:
#      |              time: time asked for
#      |              tolerance: admited deviation of start time
#      |      Returns:
#      |              list of events
#      |
#      |  quantize(self, beatDivision)
#      |      Quantize events
#      |
#      |
#      |      Args:
#      |              beatDivision : the fraction of beat that we want to quantize to
#      |
#      |  removeOverlapped(self, usePitchValues=False)
#      |      remove overlapped elements
#      |
#      |      Args:
#      |              usePitchValues : use pitch to discriminate events
#      |
#      |  reorderEvents(self)
#      |      ensure than our internal event list `events` is time sorted
#      |
#      |      can be useful for time sensitive events iteration
#      |
#      |  setDurationFromLastEvent(self, onlyIfBigger=True)
#      |      sets duration to last event NoteOff
#      |
#      |      Args:
#      |              onlyIfBigger: update duration only if last Note off is bigger
#      |
#      |      if inner events have a bigger time span than self.duration, increase duration to fit
#      |
#      |  splitInEqualLengthPatterns(self, desiredLength, trimEnd=True, copy=True)
#      |      splits a pattern in consecutive equal length cuts
#      |
#      |      Args:
#      |              desiredLength: length desired for each pattern
#      |              trimEnd : trim the end to exact desiredLength
#      |              copy: retruns a distinc copy of original pattern events, if you don't need original pattern anymore setting it to False will increase speed
#      |
#      |      Returns:
#      |              a list of patterns of length desiredLength
#      |
#      |  timeStretch(self, ratio)
#      |      time  stretch a pattern
#      |
#      |      Args:
#      |              ratio : the ratio used for time stretching
#      |
#      |  toJSONDict(self)
#      |      gives a standard dict for json output
#      |
#      |  toMIDI(self, midiMap=None, path='output/', name='test')
#      |      Function to write GSPattern instance to MIDI
#      |      Args:
#      |          midiMap: mapping used to translate tags to MIDI pitch
#      |          path: folder where MIDI file is stored
#      |          name: name of the file
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data and other attributes defined here:
#      |
#      |  defaultBPM = 120
#      |
#      |  defaultTimeSignature = [4, 4]
#
#     class GSPatternEvent(__builtin__.object)
#      |  Represent an event of a GSPattern
#      |
#      |  an event is made of start and length , origin pitch , velocity and associated tags
#      |
#      |
#      |  Attributes:
#      |          startTime: startTime of event
#      |          duration: duration of event
#      |          pitch : pitch of event
#      |          velocity: velocity of event
#      |          tags: list of tags representing the event
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, startTime, duration, pitch, velocity=127, tags=[])
#      |
#      |  __repr__(self)
#      |
#      |  allTagsAreEqualWith(self, event)
#      |      Compare this event's tags with an other event
#      |
#      |      Args:
#      |              event: event to compare with
#      |      Returns:
#      |              true if all tags are equal
#      |
#      |  copy(self)
#      |      Copy an event
#      |
#      |      Returns:
#      |               A deep copy of this event to be manipulated without changing original
#      |
#      |  cutInSteps(self, stepSize)
#      |      Cut an event in steps of stepsize length
#      |
#      |      Args:
#      |              stepSize: the desired size of each produced events
#      |      Returns:
#      |              a list of events of length `stepSize`
#      |
#      |  getEndTime(self)
#      |      returns the time when this events ends
#      |
#      |      Returns:
#      |              the time when this event ends
#      |
#      |  hasOneCommonTagWith(self, event)
#      |      compare tags between events
#      |
#      |      Args:
#      |              event: event to compare with
#      |      Returns:
#      |              true if at least one tag is equal
#      |
#      |  hasOneOfTags(self, tags)
#      |      Compare this event's tags with a list of strings
#      |
#      |      Args:
#      |              tags: list of strings to compare with
#      |      Returns:
#      |              true if at least one tag is equal
#      |
#      |  tagsAre(self, tags)
#      |      Compare this event's tags with a list of strings
#      |
#      |      Args:
#      |              tags: list of strings to compare with
#      |      Returns:
#      |              true if all tags are equal
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
#      |      list of weak references to the object (if defined)
#
# DATA
#     __loader__ = <zipimporter object "/Library/Frameworks/Python....hon2.7...
#     patternLog = <gsapi.GSLogging.ColoredLogger object>

# %% [markdown]
# ## Drum and bass generative example

# %% [markdown]
# ### Bassmine example

# %% [markdown]
# Following script commands present examples of Bassline rhythmic analysis for generative processes using GS-API.

# %%
import gsapi.GSBassmineAnalysis as bassmine
import gsapi.GSBassmineMarkov as markov
import json
import csv
import random

# %% [markdown]
# First step is to determine the datasets to use. In this case we need to provide a dataset that contains MIDI clips of basslines and drums in pairs. That means that each bass MIDI file has an associated drum MIDI file.
#
# The implemented algorithm builds two Markov models.
#
# First, contains the transition probabilities between bass beat patterns (temporal)
# Second, contains the concurrency probabilities between kick-drum and bass beat patterns.
# Moreover, the initial probabilites of events are computed, used to trigger the generation.

# %%
# STYLE DICTIONARY
style = {1: 'booka_shade', 2: 'mr_scruff'}

# SELECT STYLE
style_id = 2

bass_path = '../corpus/bassmine/' + style[style_id] + '/bass'
drum_path = '../corpus/bassmine/' + style[style_id] + '/drums'

# %% [markdown]
# The implemented algorithm in [bassmine.corpus_analysis] builds two Markov models.
#
# - Transition probabilities between bass beat patterns (temporal).
# - Concurrency probabilities between kick-drum and bass beat patterns (interlocking).
#
# Moreover, the initial probabilites of events are computed, used to trigger the generation.

# %%
# Analyse corpus and build Markov model
MM, kick_patterns = bassmine.corpus_analysis(bass_path, drum_path)
# Normalize transition matrices
MM.normalize_model()
# Out:
# [gsapi.GSIO          ][INFO   ]  start processing bass_Beyond.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing bass_Beyond.mid
# [gsapi.GSIO          ][INFO   ]  bass_Beyond.mid : getting track : 0 bass_Beyond (GSIO.py:150)
# INFO:gsapi.GSIO:bass_Beyond.mid : getting track : 0 bass_Beyond
# Bass Files
#
# Number of files:  26
#
# Drums Files
#
# Number of files:  26
# Bass file:  ../corpus/bassmine/mr_scruff/bass/bass_Beyond.mid
# Drum file:  ../corpus/bassmine/mr_scruff/drums/drums_Beyond.mid
# Bey
#
# # of beats:
# [gsapi.GSIO          ][INFO   ]  start processing drums_Beyond.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing drums_Beyond.mid
# [gsapi.GSIO          ][INFO   ]  drums_Beyond.mid : getting track : 0 drums_Beyond (GSIO.py:150)
# INFO:gsapi.GSIO:drums_Beyond.mid : getting track : 0 drums_Beyond
# [gsapi.GSIO          ][INFO   ]  drums_Beyond.mid : no tags found for pitch 38 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_Beyond.mid : no tags found for pitch 38 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_Beyond.mid : no tags found for pitch 42 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_Beyond.mid : no tags found for pitch 42 on channel 0
# [gsapi.GSIO          ][INFO   ]  start processing bass_BunchOfKeys.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing bass_BunchOfKeys.mid
# [gsapi.GSIO          ][INFO   ]  bass_BunchOfKeys.mid : getting track : 0 bass_BunchOfKeys (GSIO.py:150)
# INFO:gsapi.GSIO:bass_BunchOfKeys.mid : getting track : 0 bass_BunchOfKeys
# [gsapi.GSIO          ][INFO   ]  start processing drums_BunchOfKeys.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing drums_BunchOfKeys.mid
# [gsapi.GSIO          ][INFO   ]  drums_BunchOfKeys.mid : getting track : 0 drums_BunchOfKeys (GSIO.py:150)
# INFO:gsapi.GSIO:drums_BunchOfKeys.mid : getting track : 0 drums_BunchOfKeys
# [gsapi.GSIO          ][INFO   ]  drums_BunchOfKeys.mid : no tags found for pitch 47 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_BunchOfKeys.mid : no tags found for pitch 47 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_BunchOfKeys.mid : no tags found for pitch 42 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_BunchOfKeys.mid : no tags found for pitch 42 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_BunchOfKeys.mid : no tags found for pitch 48 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_BunchOfKeys.mid : no tags found for pitch 48 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_BunchOfKeys.mid : no tags found for pitch 38 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_BunchOfKeys.mid : no tags found for pitch 38 on channel 0
# [gsapi.GSIO          ][INFO   ]  start processing bass_ChampionNibble.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing bass_ChampionNibble.mid
# [gsapi.GSIO          ][INFO   ]  bass_ChampionNibble.mid : getting track : 0 bass_ChampionNibble (GSIO.py:150)
# INFO:gsapi.GSIO:bass_ChampionNibble.mid : getting track : 0 bass_ChampionNibble
# [gsapi.GSIO          ][INFO   ]  start processing drums_ChampionNibble.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing drums_ChampionNibble.mid
# [gsapi.GSIO          ][INFO   ]  drums_ChampionNibble.mid : getting track : 0 drums_ChampionNibble (GSIO.py:150)
# INFO:gsapi.GSIO:drums_ChampionNibble.mid : getting track : 0 drums_ChampionNibble
# [gsapi.GSIO          ][INFO   ]  drums_ChampionNibble.mid : no tags found for pitch 51 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_ChampionNibble.mid : no tags found for pitch 51 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_ChampionNibble.mid : no tags found for pitch 38 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_ChampionNibble.mid : no tags found for pitch 38 on channel 0
# [gsapi.GSIO          ][INFO   ]  start processing bass_ComeOnGrandad.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing bass_ComeOnGrandad.mid
# [gsapi.GSIO          ][INFO   ]  bass_ComeOnGrandad.mid : getting track : 0 bass_ComeOnGrandad (GSIO.py:150)
# INFO:gsapi.GSIO:bass_ComeOnGrandad.mid : getting track : 0 bass_ComeOnGrandad
# [gsapi.GSIO          ][INFO   ]  start processing drums_ComeOnGrandad.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing drums_ComeOnGrandad.mid
# [gsapi.GSIO          ][INFO   ]  drums_ComeOnGrandad.mid : getting track : 0 drums_ComeOnGrandad (GSIO.py:150)
# INFO:gsapi.GSIO:drums_ComeOnGrandad.mid : getting track : 0 drums_ComeOnGrandad
# [gsapi.GSIO          ][INFO   ]  drums_ComeOnGrandad.mid : no tags found for pitch 46 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_ComeOnGrandad.mid : no tags found for pitch 46 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_ComeOnGrandad.mid : no tags found for pitch 38 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_ComeOnGrandad.mid : no tags found for pitch 38 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_ComeOnGrandad.mid : no tags found for pitch 42 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_ComeOnGrandad.mid : no tags found for pitch 42 on channel 0
# [gsapi.GSIO          ][INFO   ]  start processing bass_Crisps.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing bass_Crisps.mid
# [gsapi.GSIO          ][INFO   ]  bass_Crisps.mid : getting track : 0 bass_Crisps (GSIO.py:150)
# INFO:gsapi.GSIO:bass_Crisps.mid : getting track : 0 bass_Crisps
#  36.0
#
# # of beats:  32.0
# Bass file:  ../corpus/bassmine/mr_scruff/bass/bass_BunchOfKeys.mid
# Drum file:  ../corpus/bassmine/mr_scruff/drums/drums_BunchOfKeys.mid
# BunchOfK
#
# # of beats:  32.0
#
# # of beats:  32.0
# Bass file:  ../corpus/bassmine/mr_scruff/bass/bass_ChampionNibble.mid
# Drum file:  ../corpus/bassmine/mr_scruff/drums/drums_ChampionNibble.mid
# ChampionNib
#
# # of beats:  32.0
#
# # of beats:  32.0
# Bass file:  ../corpus/bassmine/mr_scruff/bass/bass_ComeOnGrandad.mid
# Drum file:  ../corpus/bassmine/mr_scruff/drums/drums_ComeOnGrandad.mid
# ComeOnGran
#
# # of beats:  32.0
#
# # of beats:  32.0
# Bass file:  ../corpus/bassmine/mr_scruff/bass/bass_Crisps.mid
# Drum file:  ../corpus/bassmine/mr_scruff/drums/drums_Crisps.mid
# Cri
#
# # of beats:
# [gsapi.GSIO          ][INFO   ]  start processing drums_Crisps.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing drums_Crisps.mid
# [gsapi.GSIO          ][INFO   ]  drums_Crisps.mid : getting track : 0 drums_Crisps (GSIO.py:150)
# INFO:gsapi.GSIO:drums_Crisps.mid : getting track : 0 drums_Crisps
# [gsapi.GSIO          ][INFO   ]  drums_Crisps.mid : no tags found for pitch 42 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_Crisps.mid : no tags found for pitch 42 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_Crisps.mid : no tags found for pitch 38 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_Crisps.mid : no tags found for pitch 38 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_Crisps.mid : no tags found for pitch 46 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_Crisps.mid : no tags found for pitch 46 on channel 0
# [gsapi.GSIO          ][INFO   ]  start processing bass_DonkeyRide.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing bass_DonkeyRide.mid
# [gsapi.GSIO          ][INFO   ]  bass_DonkeyRide.mid : getting track : 0 bass_DonkeyRide (GSIO.py:150)
# INFO:gsapi.GSIO:bass_DonkeyRide.mid : getting track : 0 bass_DonkeyRide
# [gsapi.GSIO          ][INFO   ]  start processing drums_DonkeyRide.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing drums_DonkeyRide.mid
# [gsapi.GSIO          ][INFO   ]  drums_DonkeyRide.mid : getting track : 0 drums_DonkeyRide (GSIO.py:150)
# INFO:gsapi.GSIO:drums_DonkeyRide.mid : getting track : 0 drums_DonkeyRide
# [gsapi.GSIO          ][INFO   ]  drums_DonkeyRide.mid : no tags found for pitch 49 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_DonkeyRide.mid : no tags found for pitch 49 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_DonkeyRide.mid : no tags found for pitch 51 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_DonkeyRide.mid : no tags found for pitch 51 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_DonkeyRide.mid : no tags found for pitch 42 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_DonkeyRide.mid : no tags found for pitch 42 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_DonkeyRide.mid : no tags found for pitch 38 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_DonkeyRide.mid : no tags found for pitch 38 on channel 0
# [gsapi.GSIO          ][INFO   ]  start processing bass_GetAMoveOn.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing bass_GetAMoveOn.mid
# [gsapi.GSIO          ][INFO   ]  bass_GetAMoveOn.mid : getting track : 0 bass_GetAMoveOn (GSIO.py:150)
# INFO:gsapi.GSIO:bass_GetAMoveOn.mid : getting track : 0 bass_GetAMoveOn
# [gsapi.GSIO          ][INFO   ]  start processing drums_GetAMoveOn.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing drums_GetAMoveOn.mid
# [gsapi.GSIO          ][INFO   ]  drums_GetAMoveOn.mid : getting track : 0 drums_GetAMoveOn (GSIO.py:150)
# INFO:gsapi.GSIO:drums_GetAMoveOn.mid : getting track : 0 drums_GetAMoveOn
# [gsapi.GSIO          ][INFO   ]  drums_GetAMoveOn.mid : no tags found for pitch 42 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_GetAMoveOn.mid : no tags found for pitch 42 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_GetAMoveOn.mid : no tags found for pitch 38 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_GetAMoveOn.mid : no tags found for pitch 38 on channel 0
# [gsapi.GSIO          ][INFO   ]  start processing bass_GiantPickle.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing bass_GiantPickle.mid
# [gsapi.GSIO          ][INFO   ]  bass_GiantPickle.mid : getting track : 0 bass_GiantPickle (GSIO.py:150)
# INFO:gsapi.GSIO:bass_GiantPickle.mid : getting track : 0 bass_GiantPickle
# [gsapi.GSIO          ][INFO   ]  start processing drums_GiantPickle.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing drums_GiantPickle.mid
# [gsapi.GSIO          ][INFO   ]  drums_GiantPickle.mid : getting track : 0 drums_GiantPickle (GSIO.py:150)
# INFO:gsapi.GSIO:drums_GiantPickle.mid : getting track : 0 drums_GiantPickle
# [gsapi.GSIO          ][INFO   ]  drums_GiantPickle.mid : no tags found for pitch 42 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_GiantPickle.mid : no tags found for pitch 42 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_GiantPickle.mid : no tags found for pitch 38 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_GiantPickle.mid : no tags found for pitch 38 on channel 0
# [gsapi.GSIO          ][INFO   ]  start processing bass_Giffin.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing bass_Giffin.mid
# [gsapi.GSIO          ][INFO   ]  bass_Giffin.mid : getting track : 0 bass_Giffin (GSIO.py:150)
# INFO:gsapi.GSIO:bass_Giffin.mid : getting track : 0 bass_Giffin
# [gsapi.GSIO          ][INFO   ]  start processing drums_Giffin.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing drums_Giffin.mid
# [gsapi.GSIO          ][INFO   ]  drums_Giffin.mid : getting track : 0 drums_Giffin (GSIO.py:150)
# INFO:gsapi.GSIO:drums_Giffin.mid : getting track : 0 drums_Giffin
# [gsapi.GSIO          ][INFO   ]  drums_Giffin.mid : no tags found for pitch 42 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_Giffin.mid : no tags found for pitch 42 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_Giffin.mid : no tags found for pitch 38 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_Giffin.mid : no tags found for pitch 38 on channel 0
#  32.0
#
# # of beats:  32.0
# Bass file:  ../corpus/bassmine/mr_scruff/bass/bass_DonkeyRide.mid
# Drum file:  ../corpus/bassmine/mr_scruff/drums/drums_DonkeyRide.mid
# DonkeyR
#
# # of beats:  32.0
#
# # of beats:  32.0
# Bass file:  ../corpus/bassmine/mr_scruff/bass/bass_GetAMoveOn.mid
# Drum file:  ../corpus/bassmine/mr_scruff/drums/drums_GetAMoveOn.mid
# GetAMov
#
# # of beats:  32.0
#
# # of beats:  32.0
# Bass file:  ../corpus/bassmine/mr_scruff/bass/bass_GiantPickle.mid
# Drum file:  ../corpus/bassmine/mr_scruff/drums/drums_GiantPickle.mid
# GiantPic
#
# # of beats:  32.0
#
# # of beats:  32.0
# Bass file:  ../corpus/bassmine/mr_scruff/bass/bass_Giffin.mid
# Drum file:  ../corpus/bassmine/mr_scruff/drums/drums_Giffin.mid
# Gif
#
# # of beats:  32.0
#
# # of beats:
# [gsapi.GSIO          ][INFO   ]  start processing bass_GiveUpToGet.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing bass_GiveUpToGet.mid
# [gsapi.GSIO          ][INFO   ]  bass_GiveUpToGet.mid : getting track : 0 bass_GiveUpToGet (GSIO.py:150)
# INFO:gsapi.GSIO:bass_GiveUpToGet.mid : getting track : 0 bass_GiveUpToGet
# [gsapi.GSIO          ][INFO   ]  start processing drums_GiveUpToGet.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing drums_GiveUpToGet.mid
# [gsapi.GSIO          ][INFO   ]  drums_GiveUpToGet.mid : getting track : 0 drums_GiveUpToGet (GSIO.py:150)
# INFO:gsapi.GSIO:drums_GiveUpToGet.mid : getting track : 0 drums_GiveUpToGet
# [gsapi.GSIO          ][INFO   ]  drums_GiveUpToGet.mid : no tags found for pitch 42 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_GiveUpToGet.mid : no tags found for pitch 42 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_GiveUpToGet.mid : no tags found for pitch 38 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_GiveUpToGet.mid : no tags found for pitch 38 on channel 0
# [gsapi.GSIO          ][INFO   ]  start processing bass_HairyBumpercress.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing bass_HairyBumpercress.mid
# [gsapi.GSIO          ][INFO   ]  bass_HairyBumpercress.mid : getting track : 0 bass_HairyBumpercress (GSIO.py:150)
# INFO:gsapi.GSIO:bass_HairyBumpercress.mid : getting track : 0 bass_HairyBumpercress
# [gsapi.GSIO          ][INFO   ]  start processing drums_HairyBumpercress.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing drums_HairyBumpercress.mid
# [gsapi.GSIO          ][INFO   ]  drums_HairyBumpercress.mid : getting track : 0 drums_HairyBumpercress (GSIO.py:150)
# INFO:gsapi.GSIO:drums_HairyBumpercress.mid : getting track : 0 drums_HairyBumpercress
# [gsapi.GSIO          ][INFO   ]  drums_HairyBumpercress.mid : no tags found for pitch 42 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_HairyBumpercress.mid : no tags found for pitch 42 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_HairyBumpercress.mid : no tags found for pitch 46 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_HairyBumpercress.mid : no tags found for pitch 46 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_HairyBumpercress.mid : no tags found for pitch 44 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_HairyBumpercress.mid : no tags found for pitch 44 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_HairyBumpercress.mid : no tags found for pitch 51 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_HairyBumpercress.mid : no tags found for pitch 51 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_HairyBumpercress.mid : no tags found for pitch 39 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_HairyBumpercress.mid : no tags found for pitch 39 on channel 0
# [gsapi.GSIO          ][INFO   ]  start processing bass_HoldOn.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing bass_HoldOn.mid
# [gsapi.GSIO          ][INFO   ]  bass_HoldOn.mid : getting track : 0 bass_HoldOn (GSIO.py:150)
# INFO:gsapi.GSIO:bass_HoldOn.mid : getting track : 0 bass_HoldOn
# [gsapi.GSIO          ][INFO   ]  start processing drums_HoldOn.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing drums_HoldOn.mid
# [gsapi.GSIO          ][INFO   ]  drums_HoldOn.mid : getting track : 0 drums_HoldOn (GSIO.py:150)
# INFO:gsapi.GSIO:drums_HoldOn.mid : getting track : 0 drums_HoldOn
# [gsapi.GSIO          ][INFO   ]  drums_HoldOn.mid : no tags found for pitch 42 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_HoldOn.mid : no tags found for pitch 42 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_HoldOn.mid : no tags found for pitch 38 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_HoldOn.mid : no tags found for pitch 38 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_HoldOn.mid : no tags found for pitch 39 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_HoldOn.mid : no tags found for pitch 39 on channel 0
# [gsapi.GSIO          ][INFO   ]  start processing bass_JazzPotato.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing bass_JazzPotato.mid
# [gsapi.GSIO          ][INFO   ]  bass_JazzPotato.mid : getting track : 0 bass_JazzPotato (GSIO.py:150)
# INFO:gsapi.GSIO:bass_JazzPotato.mid : getting track : 0 bass_JazzPotato
# [gsapi.GSIO          ][INFO   ]  start processing drums_JazzPotato.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing drums_JazzPotato.mid
# [gsapi.GSIO          ][INFO   ]  drums_JazzPotato.mid : getting track : 0 drums_JazzPotato (GSIO.py:150)
# INFO:gsapi.GSIO:drums_JazzPotato.mid : getting track : 0 drums_JazzPotato
# [gsapi.GSIO          ][INFO   ]  drums_JazzPotato.mid : no tags found for pitch 42 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_JazzPotato.mid : no tags found for pitch 42 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_JazzPotato.mid : no tags found for pitch 38 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_JazzPotato.mid : no tags found for pitch 38 on channel 0
# [gsapi.GSIO          ][INFO   ]  start processing bass_Kalimba.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing bass_Kalimba.mid
# [gsapi.GSIO          ][INFO   ]  bass_Kalimba.mid : getting track : 0 bass_Kalimba (GSIO.py:150)
# INFO:gsapi.GSIO:bass_Kalimba.mid : getting track : 0 bass_Kalimba
#  36.0
# Bass file:  ../corpus/bassmine/mr_scruff/bass/bass_GiveUpToGet.mid
# Drum file:  ../corpus/bassmine/mr_scruff/drums/drums_GiveUpToGet.mid
# GiveUpTo
#
# # of beats:  32.0
#
# # of beats:  32.0
# Bass file:  ../corpus/bassmine/mr_scruff/bass/bass_HairyBumpercress.mid
# Drum file:  ../corpus/bassmine/mr_scruff/drums/drums_HairyBumpercress.mid
# HairyBumpercr
#
# # of beats:  32.0
#
# # of beats:  32.0
# Bass file:  ../corpus/bassmine/mr_scruff/bass/bass_HoldOn.mid
# Drum file:  ../corpus/bassmine/mr_scruff/drums/drums_HoldOn.mid
# Hol
#
# # of beats:  32.0
#
# # of beats:  32.0
# Bass file:  ../corpus/bassmine/mr_scruff/bass/bass_JazzPotato.mid
# Drum file:  ../corpus/bassmine/mr_scruff/drums/drums_JazzPotato.mid
# JazzPot
#
# # of beats:  32.0
#
# # of beats:  32.0
# Bass file:  ../corpus/bassmine/mr_scruff/bass/bass_Kalimba.mid
# Drum file:  ../corpus/bassmine/mr_scruff/drums/drums_Kalimba.mid
# Kali
#
# # of beats:
# [gsapi.GSIO          ][INFO   ]  start processing drums_Kalimba.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing drums_Kalimba.mid
# [gsapi.GSIO          ][INFO   ]  drums_Kalimba.mid : getting track : 0 drums_Kalimba (GSIO.py:150)
# INFO:gsapi.GSIO:drums_Kalimba.mid : getting track : 0 drums_Kalimba
# [gsapi.GSIO          ][INFO   ]  drums_Kalimba.mid : no tags found for pitch 42 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_Kalimba.mid : no tags found for pitch 42 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_Kalimba.mid : no tags found for pitch 51 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_Kalimba.mid : no tags found for pitch 51 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_Kalimba.mid : no tags found for pitch 49 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_Kalimba.mid : no tags found for pitch 49 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_Kalimba.mid : no tags found for pitch 38 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_Kalimba.mid : no tags found for pitch 38 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_Kalimba.mid : no tags found for pitch 39 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_Kalimba.mid : no tags found for pitch 39 on channel 0
# [gsapi.GSIO          ][INFO   ]  start processing bass_LimbicFunk.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing bass_LimbicFunk.mid
# [gsapi.GSIO          ][INFO   ]  bass_LimbicFunk.mid : getting track : 0 bass_LimbicFunk (GSIO.py:150)
# INFO:gsapi.GSIO:bass_LimbicFunk.mid : getting track : 0 bass_LimbicFunk
# [gsapi.GSIO          ][INFO   ]  start processing drums_LimbicFunk.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing drums_LimbicFunk.mid
# [gsapi.GSIO          ][INFO   ]  drums_LimbicFunk.mid : getting track : 0 drums_LimbicFunk (GSIO.py:150)
# INFO:gsapi.GSIO:drums_LimbicFunk.mid : getting track : 0 drums_LimbicFunk
# [gsapi.GSIO          ][INFO   ]  drums_LimbicFunk.mid : no tags found for pitch 46 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_LimbicFunk.mid : no tags found for pitch 46 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_LimbicFunk.mid : no tags found for pitch 38 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_LimbicFunk.mid : no tags found for pitch 38 on channel 0
# [gsapi.GSIO          ][INFO   ]  start processing bass_MusicTakesMeUp.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing bass_MusicTakesMeUp.mid
# [gsapi.GSIO          ][INFO   ]  bass_MusicTakesMeUp.mid : getting track : 0 bass_MusicTakesMeUp (GSIO.py:150)
# INFO:gsapi.GSIO:bass_MusicTakesMeUp.mid : getting track : 0 bass_MusicTakesMeUp
# [gsapi.GSIO          ][INFO   ]  start processing drums_MusicTakesMeUp.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing drums_MusicTakesMeUp.mid
# [gsapi.GSIO          ][INFO   ]  drums_MusicTakesMeUp.mid : getting track : 0 drums_MusicTakesMeUp (GSIO.py:150)
# INFO:gsapi.GSIO:drums_MusicTakesMeUp.mid : getting track : 0 drums_MusicTakesMeUp
# [gsapi.GSIO          ][INFO   ]  drums_MusicTakesMeUp.mid : no tags found for pitch 51 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_MusicTakesMeUp.mid : no tags found for pitch 51 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_MusicTakesMeUp.mid : no tags found for pitch 38 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_MusicTakesMeUp.mid : no tags found for pitch 38 on channel 0
# [gsapi.GSIO          ][INFO   ]  start processing bass_NightTime.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing bass_NightTime.mid
# [gsapi.GSIO          ][INFO   ]  bass_NightTime.mid : getting track : 0 drums_NightTiime (GSIO.py:150)
# INFO:gsapi.GSIO:bass_NightTime.mid : getting track : 0 drums_NightTiime
# [gsapi.GSIO          ][INFO   ]  start processing drums_NightTime.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing drums_NightTime.mid
# [gsapi.GSIO          ][INFO   ]  drums_NightTime.mid : getting track : 0 drums_NighTiime (GSIO.py:150)
# INFO:gsapi.GSIO:drums_NightTime.mid : getting track : 0 drums_NighTiime
# [gsapi.GSIO          ][INFO   ]  drums_NightTime.mid : no tags found for pitch 51 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_NightTime.mid : no tags found for pitch 51 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_NightTime.mid : no tags found for pitch 42 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_NightTime.mid : no tags found for pitch 42 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_NightTime.mid : no tags found for pitch 38 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_NightTime.mid : no tags found for pitch 38 on channel 0
# [gsapi.GSIO          ][INFO   ]  start processing bass_RockingChair.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing bass_RockingChair.mid
# [gsapi.GSIO          ][INFO   ]  bass_RockingChair.mid : getting track : 0 bass_RockingChair (GSIO.py:150)
# INFO:gsapi.GSIO:bass_RockingChair.mid : getting track : 0 bass_RockingChair
#  32.0
#
# # of beats:  32.0
# Bass file:  ../corpus/bassmine/mr_scruff/bass/bass_LimbicFunk.mid
# Drum file:  ../corpus/bassmine/mr_scruff/drums/drums_LimbicFunk.mid
# LimbicF
#
# # of beats:  32.0
#
# # of beats:  32.0
# Bass file:  ../corpus/bassmine/mr_scruff/bass/bass_MusicTakesMeUp.mid
# Drum file:  ../corpus/bassmine/mr_scruff/drums/drums_MusicTakesMeUp.mid
# MusicTakesM
#
# # of beats:  32.0
#
# # of beats:  32.0
# Bass file:  ../corpus/bassmine/mr_scruff/bass/bass_NightTime.mid
# Drum file:  ../corpus/bassmine/mr_scruff/drums/drums_NightTime.mid
# NightT
#
# # of beats:  32.0
#
# # of beats:  32.0
# Bass file:  ../corpus/bassmine/mr_scruff/bass/bass_RockingChair.mid
# Drum file:  ../corpus/bassmine/mr_scruff/drums/drums_RockingChair.mid
# RockingCh
#
# # of beats:
# [gsapi.GSIO          ][INFO   ]  start processing drums_RockingChair.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing drums_RockingChair.mid
# [gsapi.GSIO          ][INFO   ]  drums_RockingChair.mid : getting track : 0 drums_RockingChair (GSIO.py:150)
# INFO:gsapi.GSIO:drums_RockingChair.mid : getting track : 0 drums_RockingChair
# [gsapi.GSIO          ][INFO   ]  drums_RockingChair.mid : no tags found for pitch 51 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_RockingChair.mid : no tags found for pitch 51 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_RockingChair.mid : no tags found for pitch 46 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_RockingChair.mid : no tags found for pitch 46 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_RockingChair.mid : no tags found for pitch 38 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_RockingChair.mid : no tags found for pitch 38 on channel 0
# [gsapi.GSIO          ][INFO   ]  start processing bass_SeaMammal.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing bass_SeaMammal.mid
# [gsapi.GSIO          ][INFO   ]  bass_SeaMammal.mid : getting track : 0 bass_SeaMammal (GSIO.py:150)
# INFO:gsapi.GSIO:bass_SeaMammal.mid : getting track : 0 bass_SeaMammal
# [gsapi.GSIO          ][INFO   ]  start processing drums_SeaMammal.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing drums_SeaMammal.mid
# [gsapi.GSIO          ][INFO   ]  drums_SeaMammal.mid : getting track : 0 drums_SeaMammal (GSIO.py:150)
# INFO:gsapi.GSIO:drums_SeaMammal.mid : getting track : 0 drums_SeaMammal
# [gsapi.GSIO          ][INFO   ]  drums_SeaMammal.mid : no tags found for pitch 42 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_SeaMammal.mid : no tags found for pitch 42 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_SeaMammal.mid : no tags found for pitch 37 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_SeaMammal.mid : no tags found for pitch 37 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_SeaMammal.mid : no tags found for pitch 38 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_SeaMammal.mid : no tags found for pitch 38 on channel 0
# [gsapi.GSIO          ][INFO   ]  start processing bass_ShantyTown.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing bass_ShantyTown.mid
# [gsapi.GSIO          ][INFO   ]  bass_ShantyTown.mid : getting track : 0 bass_ShantyTown (GSIO.py:150)
# INFO:gsapi.GSIO:bass_ShantyTown.mid : getting track : 0 bass_ShantyTown
# [gsapi.GSIO          ][INFO   ]  start processing drums_ShantyTown.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing drums_ShantyTown.mid
# [gsapi.GSIO          ][INFO   ]  drums_ShantyTown.mid : getting track : 0 drums_ShantyTown (GSIO.py:150)
# INFO:gsapi.GSIO:drums_ShantyTown.mid : getting track : 0 drums_ShantyTown
# [gsapi.GSIO          ][INFO   ]  drums_ShantyTown.mid : no tags found for pitch 51 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_ShantyTown.mid : no tags found for pitch 51 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_ShantyTown.mid : no tags found for pitch 42 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_ShantyTown.mid : no tags found for pitch 42 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_ShantyTown.mid : no tags found for pitch 38 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_ShantyTown.mid : no tags found for pitch 38 on channel 0
# [gsapi.GSIO          ][INFO   ]  start processing bass_SoLong.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing bass_SoLong.mid
# [gsapi.GSIO          ][INFO   ]  bass_SoLong.mid : getting track : 0 bass_SoLong (GSIO.py:150)
# INFO:gsapi.GSIO:bass_SoLong.mid : getting track : 0 bass_SoLong
# [gsapi.GSIO          ][INFO   ]  start processing drums_SoLong.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing drums_SoLong.mid
# [gsapi.GSIO          ][INFO   ]  drums_SoLong.mid : getting track : 0 drums_SoLong (GSIO.py:150)
# INFO:gsapi.GSIO:drums_SoLong.mid : getting track : 0 drums_SoLong
# [gsapi.GSIO          ][INFO   ]  drums_SoLong.mid : no tags found for pitch 42 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_SoLong.mid : no tags found for pitch 42 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_SoLong.mid : no tags found for pitch 38 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_SoLong.mid : no tags found for pitch 38 on channel 0
# [gsapi.GSIO          ][INFO   ]  start processing bass_SpandexMan.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing bass_SpandexMan.mid
# [gsapi.GSIO          ][INFO   ]  bass_SpandexMan.mid : getting track : 0 bass_SpandexMan (GSIO.py:150)
# INFO:gsapi.GSIO:bass_SpandexMan.mid : getting track : 0 bass_SpandexMan
# [gsapi.GSIO          ][INFO   ]  start processing drums_SpandexMan.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing drums_SpandexMan.mid
# [gsapi.GSIO          ][INFO   ]  drums_SpandexMan.mid : getting track : 0 drums_SpandexMan (GSIO.py:150)
# INFO:gsapi.GSIO:drums_SpandexMan.mid : getting track : 0 drums_SpandexMan
# [gsapi.GSIO          ][INFO   ]  drums_SpandexMan.mid : no tags found for pitch 42 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_SpandexMan.mid : no tags found for pitch 42 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_SpandexMan.mid : no tags found for pitch 48 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_SpandexMan.mid : no tags found for pitch 48 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_SpandexMan.mid : no tags found for pitch 38 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_SpandexMan.mid : no tags found for pitch 38 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_SpandexMan.mid : no tags found for pitch 47 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_SpandexMan.mid : no tags found for pitch 47 on channel 0
#  32.0
#
# # of beats:  32.0
# Bass file:  ../corpus/bassmine/mr_scruff/bass/bass_SeaMammal.mid
# Drum file:  ../corpus/bassmine/mr_scruff/drums/drums_SeaMammal.mid
# SeaMam
#
# # of beats:  32.0
#
# # of beats:  28.0
# Bass file:  ../corpus/bassmine/mr_scruff/bass/bass_ShantyTown.mid
# Drum file:  ../corpus/bassmine/mr_scruff/drums/drums_ShantyTown.mid
# ShantyT
#
# # of beats:  36.0
#
# # of beats:  32.0
# Bass file:  ../corpus/bassmine/mr_scruff/bass/bass_SoLong.mid
# Drum file:  ../corpus/bassmine/mr_scruff/drums/drums_SoLong.mid
# SoL
#
# # of beats:  32.0
#
# # of beats:  32.0
# Bass file:  ../corpus/bassmine/mr_scruff/bass/bass_SpandexMan.mid
# Drum file:  ../corpus/bassmine/mr_scruff/drums/drums_SpandexMan.mid
# Spandex
#
# # of beats:  32.0
#
# # of beats:
# [gsapi.GSIO          ][INFO   ]  start processing bass_Sweetsmoke.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing bass_Sweetsmoke.mid
# [gsapi.GSIO          ][INFO   ]  bass_Sweetsmoke.mid : getting track : 0 bass_Sweetsmoke (GSIO.py:150)
# INFO:gsapi.GSIO:bass_Sweetsmoke.mid : getting track : 0 bass_Sweetsmoke
# [gsapi.GSIO          ][INFO   ]  start processing drums_Sweetsmoke.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing drums_Sweetsmoke.mid
# [gsapi.GSIO          ][INFO   ]  drums_Sweetsmoke.mid : getting track : 0 drums_Sweetsmoke (GSIO.py:150)
# INFO:gsapi.GSIO:drums_Sweetsmoke.mid : getting track : 0 drums_Sweetsmoke
# [gsapi.GSIO          ][INFO   ]  drums_Sweetsmoke.mid : no tags found for pitch 51 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_Sweetsmoke.mid : no tags found for pitch 51 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_Sweetsmoke.mid : no tags found for pitch 42 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_Sweetsmoke.mid : no tags found for pitch 42 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_Sweetsmoke.mid : no tags found for pitch 38 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_Sweetsmoke.mid : no tags found for pitch 38 on channel 0
# [gsapi.GSIO          ][INFO   ]  start processing bass_TheClock.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing bass_TheClock.mid
# [gsapi.GSIO          ][INFO   ]  bass_TheClock.mid : getting track : 0 bass_TheClock (GSIO.py:150)
# INFO:gsapi.GSIO:bass_TheClock.mid : getting track : 0 bass_TheClock
# [gsapi.GSIO          ][INFO   ]  start processing drums_TheClock.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing drums_TheClock.mid
# [gsapi.GSIO          ][INFO   ]  drums_TheClock.mid : getting track : 0 drums_TheClock (GSIO.py:150)
# INFO:gsapi.GSIO:drums_TheClock.mid : getting track : 0 drums_TheClock
# [gsapi.GSIO          ][INFO   ]  drums_TheClock.mid : no tags found for pitch 42 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_TheClock.mid : no tags found for pitch 42 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_TheClock.mid : no tags found for pitch 38 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_TheClock.mid : no tags found for pitch 38 on channel 0
# [gsapi.GSIO          ][INFO   ]  start processing bass_ValleyOfTheSausages.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing bass_ValleyOfTheSausages.mid
# [gsapi.GSIO          ][INFO   ]  bass_ValleyOfTheSausages.mid : getting track : 0 bass_ValeyOfTheSausages (GSIO.py:150)
# INFO:gsapi.GSIO:bass_ValleyOfTheSausages.mid : getting track : 0 bass_ValeyOfTheSausages
# [gsapi.GSIO          ][INFO   ]  start processing drums_ValleyOfTheSausages.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing drums_ValleyOfTheSausages.mid
# [gsapi.GSIO          ][INFO   ]  drums_ValleyOfTheSausages.mid : getting track : 0 drums_ValleyOfTheSausages (GSIO.py:150)
# INFO:gsapi.GSIO:drums_ValleyOfTheSausages.mid : getting track : 0 drums_ValleyOfTheSausages
# [gsapi.GSIO          ][INFO   ]  drums_ValleyOfTheSausages.mid : no tags found for pitch 42 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_ValleyOfTheSausages.mid : no tags found for pitch 42 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_ValleyOfTheSausages.mid : no tags found for pitch 47 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_ValleyOfTheSausages.mid : no tags found for pitch 47 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_ValleyOfTheSausages.mid : no tags found for pitch 48 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_ValleyOfTheSausages.mid : no tags found for pitch 48 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_ValleyOfTheSausages.mid : no tags found for pitch 38 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_ValleyOfTheSausages.mid : no tags found for pitch 38 on channel 0
# [gsapi.GSIO          ][INFO   ]  start processing bass_Whiplash.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing bass_Whiplash.mid
# [gsapi.GSIO          ][INFO   ]  bass_Whiplash.mid : getting track : 0 bass_Whiplash (GSIO.py:150)
# INFO:gsapi.GSIO:bass_Whiplash.mid : getting track : 0 bass_Whiplash
# [gsapi.GSIO          ][INFO   ]  start processing drums_Whiplash.mid (GSIO.py:125)
# INFO:gsapi.GSIO:start processing drums_Whiplash.mid
# [gsapi.GSIO          ][INFO   ]  drums_Whiplash.mid : getting track : 0 drums_Whiplash (GSIO.py:150)
# INFO:gsapi.GSIO:drums_Whiplash.mid : getting track : 0 drums_Whiplash
# [gsapi.GSIO          ][INFO   ]  drums_Whiplash.mid : no tags found for pitch 42 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_Whiplash.mid : no tags found for pitch 42 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_Whiplash.mid : no tags found for pitch 38 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_Whiplash.mid : no tags found for pitch 38 on channel 0
# [gsapi.GSIO          ][INFO   ]  drums_Whiplash.mid : no tags found for pitch 49 on channel 0 (GSIO.py:170)
# INFO:gsapi.GSIO:drums_Whiplash.mid : no tags found for pitch 49 on channel 0
#  32.0
# Bass file:  ../corpus/bassmine/mr_scruff/bass/bass_Sweetsmoke.mid
# Drum file:  ../corpus/bassmine/mr_scruff/drums/drums_Sweetsmoke.mid
# Sweetsm
#
# # of beats:  32.0
#
# # of beats:  32.0
# Bass file:  ../corpus/bassmine/mr_scruff/bass/bass_TheClock.mid
# Drum file:  ../corpus/bassmine/mr_scruff/drums/drums_TheClock.mid
# TheCl
#
# # of beats:  32.0
#
# # of beats:  32.0
# Bass file:  ../corpus/bassmine/mr_scruff/bass/bass_ValleyOfTheSausages.mid
# Drum file:  ../corpus/bassmine/mr_scruff/drums/drums_ValleyOfTheSausages.mid
# ValleyOfTheSausa
#
# # of beats:  32.0
#
# # of beats:  32.0
# Bass file:  ../corpus/bassmine/mr_scruff/bass/bass_Whiplash.mid
# Drum file:  ../corpus/bassmine/mr_scruff/drums/drums_Whiplash.mid
# Whipl
#
# # of beats:  36.0
#
# # of beats:  32.0

# %% [markdown]
# Once models are computed we can export them.

# %%
# Output folder (to use with Max this folder should be Bassmine-master/models/)
_path = 'tutorial-4/output/'
#  Uncomment to create models and export to pickle. REQUIRED to add new collections and use them in Max app.
# Export to pickle files
bassmine.write2pickle('initial', MM.get_initial(),_path + style[style_id] + '/')
bassmine.write2pickle('temporal', MM.get_temporal(),_path + style[style_id] + '/')
bassmine.write2pickle('interlocking', MM.get_interlocking(),_path + style[style_id] + '/')

# %% [markdown]
# #### Stylistic transformations using Markov Models with constraints

# %%
# Compute Rhythm Homogeneous MM (HMM) and export to JSON
HModel = MM.rhythm_model(_path)

# %%
# Given a Kick pattern generate a NHMM with interlocking constraint
# Select a random Kick pattern from the corpus
target_kick = kick_patterns[random.randint(0,len(kick_patterns)-1)]
print target_kick
# Translate GSPattern to internal beat IDs
target_kick = bassmine.translate_rhythm(bassmine.binaryBeatPattern([e.startTime for e in target_kick.events],8))

#Compute Non-Homogenuous Interlocking Markov Model based on a target Kick pattern
NHMinter = markov.constrainMM(MM, target_kick, _path)
# Out:
# [10, 0, 3, 4, 10, 0, 3, 4, 10, 0, 3, 4, 10, 0, 3, 4, 10, 0, 3, 4, 10, 0, 3, 4, 10, 0, 3, 4, 10, 0, 3, 4]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-77904c01c8c6> in <module>()
#       4 print target_kick
#       5 # Translate GSPattern to internal beat IDs
# ----> 6 target_kick = bassmine.translate_rhythm(bassmine.binaryBeatPattern([e.startTime for e in target_kick.events],8))
#       7
#       8 #Compute Non-Homogenuous Interlocking Markov Model based on a target Kick pattern
#
# AttributeError: 'list' object has no attribute 'events'

# %%
# Create variation model (WIP) #need revision
#target_bass = [5,5,-5,5,5,-5,5,5]
#NHMvariation = markov.variationMM(MM, target_bass, _path)

# %% [markdown]
# #### Generation examples

# %%
# Example od generation without constraints. It computes Homogeneous Markov Model (HM)
pattern = markov.generateBassRhythm(MM)
pattern.toMIDI(name='regular')

# %%
# Example of generation using Interlocking constraint.
inter_pattern = markov.generateBassRhythm(MM, target=target_kick)
# Write pattern to MIDI
inter_pattern.toMIDI(name='interlock')

# %%
# Example of variation generation (Need revision!)
#var_mask = [1, 1, 1, -1, 1, 1, -1, 1]
#variation_pattern = markov.generateBassRhythmVariation(MM,inter_pattern,var_mask)
#variation_pattern.toMIDI(name='variation')
